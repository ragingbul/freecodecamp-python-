# %%
print(isinstance('Hello world', str)) # True
print(isinstance('John Doe', int)) # False
# Out:
# True
# False

# %% [markdown]
# use to check if the variable or the value is a certain data type

# %% [markdown]
# if a function does not return a value explicitly the value is automatically none

# %% [markdown]
# f-string is also known as for formatted string
