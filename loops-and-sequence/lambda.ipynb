# %% [markdown]
# As mentioned earlier, lambda functions are anonymous, so this function no longer has the name square associated with it. Lambda functions are great when you need to use them in higher order functions like this:

# %%
numbers = [1, 2, 3, 4, 5]

even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)  # [2, 4]
# Out:
# [2, 4]

# %%
numbers = [1, 2, 3, 4, 5]

square = lambda x: x ** 2
squared_numbers = list(map(square, numbers))
print(squared_numbers) # [1, 4, 9, 16, 25]
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# lambda is basically single line functions which are reasonable to use if the function conditions and operations are very small
